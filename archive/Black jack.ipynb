# %% [markdown]
# <h1>Testing</h1>

# %%
import numpy as np
import random as random
import time
import sys
from sys import exit

# %%
number = ["Ace","King","Queen","Jack",10,9,8,7,6,5,4,3,2]
numbers = [11,10,10,10,10,9,8,7,6,5,4,3,2]*4
suit = ["Clubs", "Diamonds", "Hearts", "Spades"]
len(number), len(suit)

# %%
deck = []
new_deck = []
for i in range(len(suit)):
    for j in range(len(number)):
        card = str(number[j])+' '+'of'+' '+str(suit[i])
        deck.append(card)
        new_deck.append(card)

# %%
len(new_deck)

# %%
#Initial phase, card for player,dealer,player,dealer(unknown card)
player_card = []
player_value = []
dealer_card = []
dealer_value = []
dealer_unknown = []
dealer_unknownv = []

size = len(new_deck)
r = random.randint(0,size)
player_card.append(new_deck[r])
player_value.append(numbers[r])
new_deck.pop(r)
numbers.pop(r)

size = len(new_deck)
r = random.randint(0,size)
dealer_card.append(new_deck[r])
dealer_value.append(numbers[r])
new_deck.pop(r)
numbers.pop(r)

size = len(new_deck)
r = random.randint(0,size)
player_card.append(new_deck[r])
player_value.append(numbers[r])
new_deck.pop(r)
numbers.pop(r)

size = len(new_deck)
r = random.randint(0,size)
dealer_card.append("?")
dealer_value.append("?")
dealer_unknown.append(new_deck[r])
dealer_unknown.append(numbers[r])
new_deck.pop(r)
numbers.pop(r)
size = len(new_deck)

player_card,player_value,dealer_card,dealer_value,dealer_unknown

# %%
#Dealing phase
for i in range(6):
    if sum(player_value) > 21:
        for i in range(len(player_value)):
            if player_value[i] == 11:
                player_value[i] -= 10
    print("The dealers cards are ", dealer_card)
    print("Your cards are ",player_card,"\n","You have", sum(player_value),"\n")
    
    if sum(player_value) > 21:
        print("Aww you bust :( ")
        break
    elif sum(player_value) == 21:
        print("Wow you got a 21!")
        break
    else:
        hit = str(input("Hit or stick?"))
        if hit == "stick":
            break
        elif hit == "hit":
            size = len(new_deck)
            r = random.randint(0,size)
            player_card.append(new_deck[r])
            player_value.append(numbers[r])
            new_deck.pop(r)
            numbers.pop(r)

# %% [markdown]
# <h1>bugs</h1>
# -Double ace

# %%
def blackjack():
    
    number = ["Ace","King","Queen","Jack",10,9,8,7,6,5,4,3,2]
    numbers = [11,10,10,10,10,9,8,7,6,5,4,3,2]*4
    suit = ["Clubs", "Diamonds", "Hearts", "Spades"]
    deck = []
    new_deck = []
    chips = 20
    
    for i in range(len(suit)):                                            #generating the deck
        for j in range(len(number)):
            card = str(number[j])+' '+'of'+' '+str(suit[i])
            deck.append(card)
            new_deck.append(card)
            
    x = input("Type ready to start :)  ")                                  #ready confirmation
    if x != "ready":
        return "You lose :("
    else:
        print("Great!","\n")
        time.sleep(1)
        print("You have 20 chips")
        time.sleep(1)
        print("How many chips would you like to bet?")
        bet = int(input())                                                 #bet amount
        if bet < 1 or bet > chips:
            print("Nice try, you dont have enough chips.")
        else:                                                              #initial phase
            time.sleep(1)
            print("Bets are in!")
            time.sleep(1)
            print("The dealer will now deal")
            player_card = []
            player_value = []
            dealer_card = []
            dealer_value = []
            dealer_unknown = []
            dealer_unknownv = []
            size = len(new_deck)
            r = random.randint(0,size)
            player_card.append(new_deck[r])
            player_value.append(numbers[r])
            new_deck.pop(r)
            numbers.pop(r)
            size = len(new_deck)
            r = random.randint(0,size)
            dealer_card.append(new_deck[r])
            dealer_value.append(numbers[r])
            dealer_unknown.append(new_deck[r])
            dealer_unknownv.append(numbers[r])
            new_deck.pop(r)
            numbers.pop(r)
            size = len(new_deck)
            r = random.randint(0,size)
            player_card.append(new_deck[r])
            player_value.append(numbers[r])
            new_deck.pop(r)
            numbers.pop(r)
            size = len(new_deck)
            r = random.randint(0,size)
            dealer_card.append("?")
            dealer_value.append("?")
            dealer_unknown.append(new_deck[r])
            dealer_unknownv.append(numbers[r])
            new_deck.pop(r)
            numbers.pop(r)
            size = len(new_deck)
            
            print("The dealers cards are ", dealer_card)
            
            for i in range(6):                                                    #dealing phase
                if sum(player_value) > 21:
                    for i in range(len(player_value)):  #makes ace 1 or 11
                        if player_value[i] == 11:
                            player_value[i] -= 10
                        break        
                time.sleep(1)
                print("Your cards are ",player_card)
                time.sleep(1)
                print("You have", sum(player_value),"\n")
                if len(player_value) == 2 and sum(player_value) == 21:
                    chips = chips*3
                    print("Congrats!")
                    time.sleep(1)
                    print("You got a black jack")
                    print("You now have ",chips,"chips")
                    break
                    #quit
                if sum(player_value) > 21:
                    print("Aww you bust :( ")
                    time.sleep(1)
                    print("The dealer wins!")
                    break
                    #quit
                elif sum(player_value) == 21:
                    print("Wow you got a 21!")
                    break
                else:
                    hit = str(input("Hit or stick?"))
                if hit == "stick":
                    break
                elif hit == "hit":
                    size = len(new_deck)
                    r = random.randint(0,size)
                    player_card.append(new_deck[r])
                    player_value.append(numbers[r])
                    new_deck.pop(r)
                    numbers.pop(r)

            print("The dealers cards are", dealer_unknown)
            time.sleep(1)
            print("The dealer has", sum(dealer_unknownv))
            for i in range(6):
                if sum(dealer_unknownv) < 17:
                    size = len(new_deck)
                    r = random.randint(0,size)
                    dealer_unknown.append(new_deck[r])
                    dealer_unknownv.append(numbers[r])
                    new_deck.pop(r)
                    numbers.pop(r)
                    print("The dealers cards are", dealer_unknown)
                    time.sleep(1)
                    print("The dealer has", sum(dealer_unknownv))
                elif sum(dealer_unknownv) > 21:
                    break
            
            if sum(dealer_unknownv)>21:
                print("The dealer busts!")
                time.sleep(1)
                print("You win!!")
            else:
                if sum(player_value) > sum(dealer_unknownv):
                    print("You win!!")
                    chips = chips*2
                    time.sleep(1)
                    print("You now have ", chips, "chips")
                elif sum(player_value) == sum(dealer_unknownv):
                    print("Its a draw")
                    time.sleep(1)
                    print("You now have ", chips, "chips")
                    chips = chips
                elif sum(player_value) < sum(dealer_unknownv):
                    print("Aww you lose :(")
                    chips -= bet
                    time.sleep(1)
                    print("You now have ", chips, "chips")

# %%
blackjack()
# Out:
# Type ready to start :)  ready
# Great!
#
# You have 20 chips
# How many chips would you like to bet?
# 13
# Bets are in!
# The dealer will now deal
# The dealers cards are  ['9 of Diamonds', '?']
# Your cards are  ['3 of Diamonds', '5 of Spades']
# You have 8
#
# Hit or stick?hit
# Your cards are  ['3 of Diamonds', '5 of Spades', 'King of Clubs']
# You have 18
#
# Hit or stick?stick
# The dealers cards are ['9 of Diamonds', 'Queen of Clubs']
# The dealer has 19
# Aww you lose :(
# You now have  7 chips
